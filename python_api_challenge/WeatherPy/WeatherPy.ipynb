# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [raw]
# https://api.openweathermap.org/data/2.5/weather?q={city name}&appid={API key}

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 596

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

#         # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | iroquois falls
# Processing Record 2 of Set 1 | toora-khem
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 1 | bathsheba
# Processing Record 6 of Set 1 | husavik
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | kieta
# Processing Record 9 of Set 1 | hithadhoo
# Processing Record 10 of Set 1 | itoman
# Processing Record 11 of Set 1 | victoria
# Processing Record 12 of Set 1 | maragogi
# Processing Record 13 of Set 1 | pisco
# Processing Record 14 of Set 1 | olinda
# Processing Record 15 of Set 1 | kaeo
# Processing Record 16 of Set 1 | dikson
# Processing Record 17 of Set 1 | rawson
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | biak
# Processing Record 20 of Set 1 | logstor
# Processing Record 21 of Set 1 | lukovetskiy
# Processing Record 22 of Set 1 | saint combs
# City not found. Skipping...
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | dobric
# Processing Record 25 of Set 1 | hervey bay
# Processing Record 26 of Set 1 | parvatsar
# Processing Record 27 of Set 1 | lorengau
# Processing Record 28 of Set 1 | qaanaaq
# Processing Record 29 of Set 1 | kruisfontein
# Processing Record 30 of Set 1 | boa vista
# Processing Record 31 of Set 1 | basco
# Processing Record 32 of Set 1 | palauig
# Processing Record 33 of Set 1 | saint augustine
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | campbellsville
# Processing Record 36 of Set 1 | lamar
# Processing Record 37 of Set 1 | le mars
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | hemnesberget
# Processing Record 40 of Set 1 | premia de mar
# Processing Record 41 of Set 1 | vila franca do campo
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | puro
# Processing Record 44 of Set 1 | carnarvon
# Processing Record 45 of Set 1 | ushtobe
# Processing Record 46 of Set 1 | busselton
# Processing Record 47 of Set 1 | batagay
# Processing Record 48 of Set 1 | port macquarie
# Processing Record 49 of Set 1 | chuy
# Processing Record 50 of Set 1 | taltal
# Processing Record 0 of Set 2 | yulara
# Processing Record 1 of Set 2 | sakakah
# Processing Record 2 of Set 2 | bakuriani
# Processing Record 3 of Set 2 | srednekolymsk
# Processing Record 4 of Set 2 | burayevo
# Processing Record 5 of Set 2 | baykit
# Processing Record 6 of Set 2 | hasaki
# Processing Record 7 of Set 2 | new norfolk
# Processing Record 8 of Set 2 | vao
# Processing Record 9 of Set 2 | makakilo city
# Processing Record 10 of Set 2 | bluff
# Processing Record 11 of Set 2 | sao jose da coroa grande
# Processing Record 12 of Set 2 | constitucion
# Processing Record 13 of Set 2 | hobart
# Processing Record 14 of Set 2 | jamestown
# Processing Record 15 of Set 2 | binzhou
# Processing Record 16 of Set 2 | yellowknife
# Processing Record 17 of Set 2 | chokurdakh
# Processing Record 18 of Set 2 | peniche
# Processing Record 19 of Set 2 | faanui
# Processing Record 20 of Set 2 | mar del plata
# Processing Record 21 of Set 2 | nakusp
# Processing Record 22 of Set 2 | saint-philippe
# Processing Record 23 of Set 2 | trinidad
# Processing Record 24 of Set 2 | east london
# Processing Record 25 of Set 2 | eyl
# Processing Record 26 of Set 2 | nikolskoye
# Processing Record 27 of Set 2 | port alfred
# Processing Record 28 of Set 2 | puerto ayora
# Processing Record 29 of Set 2 | victor harbor
# Processing Record 30 of Set 2 | bethel
# Processing Record 31 of Set 2 | yumen
# Processing Record 32 of Set 2 | novyy urengoy
# Processing Record 33 of Set 2 | araouane
# Processing Record 34 of Set 2 | sobolevo
# Processing Record 35 of Set 2 | caravelas
# Processing Record 36 of Set 2 | yar-sale
# Processing Record 37 of Set 2 | barrow
# Processing Record 38 of Set 2 | cape town
# Processing Record 39 of Set 2 | ribeira grande
# Processing Record 40 of Set 2 | port blair
# Processing Record 41 of Set 2 | fairbanks
# Processing Record 42 of Set 2 | saskylakh
# Processing Record 43 of Set 2 | castro
# Processing Record 44 of Set 2 | torbay
# Processing Record 45 of Set 2 | komsomolskiy
# Processing Record 46 of Set 2 | huilong
# Processing Record 47 of Set 2 | atar
# Processing Record 48 of Set 2 | narsaq
# Processing Record 49 of Set 2 | nueva loja
# Processing Record 0 of Set 3 | acapulco
# Processing Record 1 of Set 3 | saint-pierre
# Processing Record 2 of Set 3 | georgetown
# Processing Record 3 of Set 3 | port lincoln
# Processing Record 4 of Set 3 | tubruq
# City not found. Skipping...
# Processing Record 5 of Set 3 | coquimbo
# Processing Record 6 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 3 | dinsor
# City not found. Skipping...
# Processing Record 9 of Set 3 | bereda
# Processing Record 10 of Set 3 | qaqortoq
# Processing Record 11 of Set 3 | kodiak
# Processing Record 12 of Set 3 | aklavik
# Processing Record 13 of Set 3 | dhrangadhra
# Processing Record 14 of Set 3 | beringovskiy
# Processing Record 15 of Set 3 | geraldton
# Processing Record 16 of Set 3 | belmonte
# Processing Record 17 of Set 3 | arrifes
# Processing Record 18 of Set 3 | leningradskiy
# Processing Record 19 of Set 3 | arraial do cabo
# Processing Record 20 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 3 | hilo
# Processing Record 22 of Set 3 | ilulissat
# Processing Record 23 of Set 3 | half moon bay
# Processing Record 24 of Set 3 | kingaroy
# Processing Record 25 of Set 3 | kapaa
# Processing Record 26 of Set 3 | esperance
# Processing Record 27 of Set 3 | trelew
# Processing Record 28 of Set 3 | waw
# Processing Record 29 of Set 3 | guozhen
# Processing Record 30 of Set 3 | staryy nadym
# Processing Record 31 of Set 3 | kavaratti
# Processing Record 32 of Set 3 | bull savanna
# Processing Record 33 of Set 3 | college
# Processing Record 34 of Set 3 | hvolsvollur
# Processing Record 35 of Set 3 | nouakchott
# Processing Record 36 of Set 3 | port augusta
# Processing Record 37 of Set 3 | khokhlovo
# Processing Record 38 of Set 3 | khani
# Processing Record 39 of Set 3 | amot
# Processing Record 40 of Set 3 | vaini
# Processing Record 41 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 3 | wagar
# Processing Record 43 of Set 3 | portland
# Processing Record 44 of Set 3 | cherskiy
# Processing Record 45 of Set 3 | bombo
# Processing Record 46 of Set 3 | broken hill
# Processing Record 47 of Set 3 | baturaja
# Processing Record 48 of Set 3 | tarakan
# Processing Record 49 of Set 3 | coruripe
# Processing Record 0 of Set 4 | saint anthony
# Processing Record 1 of Set 4 | buraydah
# Processing Record 2 of Set 4 | airai
# Processing Record 3 of Set 4 | decatur
# Processing Record 4 of Set 4 | ahuimanu
# Processing Record 5 of Set 4 | kaitangata
# Processing Record 6 of Set 4 | port elizabeth
# Processing Record 7 of Set 4 | huayapam
# City not found. Skipping...
# Processing Record 8 of Set 4 | poltavka
# Processing Record 9 of Set 4 | kibala
# Processing Record 10 of Set 4 | ostrovnoy
# Processing Record 11 of Set 4 | bredasdorp
# Processing Record 12 of Set 4 | saryshagan
# City not found. Skipping...
# Processing Record 13 of Set 4 | tuatapere
# Processing Record 14 of Set 4 | alugan
# Processing Record 15 of Set 4 | chokwe
# Processing Record 16 of Set 4 | ormara
# Processing Record 17 of Set 4 | poum
# Processing Record 18 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 4 | atuona
# Processing Record 20 of Set 4 | jumla
# Processing Record 21 of Set 4 | tuktoyaktuk
# Processing Record 22 of Set 4 | eureka
# Processing Record 23 of Set 4 | rio branco
# Processing Record 24 of Set 4 | hamilton
# Processing Record 25 of Set 4 | lafiagi
# Processing Record 26 of Set 4 | vaitape
# Processing Record 27 of Set 4 | butaritari
# Processing Record 28 of Set 4 | benghazi
# Processing Record 29 of Set 4 | bambous virieux
# Processing Record 30 of Set 4 | tasiilaq
# Processing Record 31 of Set 4 | palestine
# Processing Record 32 of Set 4 | concepcion del oro
# Processing Record 33 of Set 4 | bilma
# Processing Record 34 of Set 4 | dubbo
# Processing Record 35 of Set 4 | marsa matruh
# Processing Record 36 of Set 4 | minchinabad
# Processing Record 37 of Set 4 | san patricio
# Processing Record 38 of Set 4 | astipalaia
# City not found. Skipping...
# Processing Record 39 of Set 4 | itamaraca
# Processing Record 40 of Set 4 | avarua
# Processing Record 41 of Set 4 | oistins
# Processing Record 42 of Set 4 | alihe
# Processing Record 43 of Set 4 | abu dhabi
# Processing Record 44 of Set 4 | la ciotat
# Processing Record 45 of Set 4 | puerto colombia
# Processing Record 46 of Set 4 | muzhi
# Processing Record 47 of Set 4 | saint george
# Processing Record 48 of Set 4 | shimoda
# Processing Record 49 of Set 4 | nome
# Processing Record 0 of Set 5 | touros
# Processing Record 1 of Set 5 | hay river
# Processing Record 2 of Set 5 | verkhnyaya tura
# Processing Record 3 of Set 5 | lebu
# Processing Record 4 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 5 of Set 5 | cabo san lucas
# Processing Record 6 of Set 5 | nuuk
# Processing Record 7 of Set 5 | thompson
# Processing Record 8 of Set 5 | braslav
# City not found. Skipping...
# Processing Record 9 of Set 5 | ouadda
# Processing Record 10 of Set 5 | furstenwalde
# Processing Record 11 of Set 5 | hofn
# Processing Record 12 of Set 5 | pleshanovo
# Processing Record 13 of Set 5 | ponta do sol
# Processing Record 14 of Set 5 | stephenville
# Processing Record 15 of Set 5 | prince rupert
# Processing Record 16 of Set 5 | blairmore
# Processing Record 17 of Set 5 | jalu
# Processing Record 18 of Set 5 | susangerd
# Processing Record 19 of Set 5 | rexburg
# Processing Record 20 of Set 5 | north bend
# Processing Record 21 of Set 5 | muros
# Processing Record 22 of Set 5 | saldanha
# Processing Record 23 of Set 5 | corinto
# Processing Record 24 of Set 5 | sabha
# Processing Record 25 of Set 5 | dois corregos
# Processing Record 26 of Set 5 | lavrentiya
# Processing Record 27 of Set 5 | naze
# Processing Record 28 of Set 5 | sitka
# Processing Record 29 of Set 5 | gwembe
# Processing Record 30 of Set 5 | cap malheureux
# Processing Record 31 of Set 5 | souillac
# Processing Record 32 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 5 | salalah
# Processing Record 34 of Set 5 | upernavik
# Processing Record 35 of Set 5 | sakaiminato
# Processing Record 36 of Set 5 | severo-kurilsk
# Processing Record 37 of Set 5 | fortuna
# Processing Record 38 of Set 5 | emerald
# Processing Record 39 of Set 5 | sala consilina
# Processing Record 40 of Set 5 | santa vitoria do palmar
# Processing Record 41 of Set 5 | tukrah
# Processing Record 42 of Set 5 | saint-joseph
# Processing Record 43 of Set 5 | adet
# Processing Record 44 of Set 5 | stabat
# Processing Record 45 of Set 5 | laguna
# Processing Record 46 of Set 5 | cartagena del chaira
# Processing Record 47 of Set 5 | pevek
# Processing Record 48 of Set 5 | broome
# Processing Record 49 of Set 5 | kerema
# Processing Record 0 of Set 6 | cayenne
# Processing Record 1 of Set 6 | itaituba
# Processing Record 2 of Set 6 | durban
# Processing Record 3 of Set 6 | yumbe
# Processing Record 4 of Set 6 | lieksa
# Processing Record 5 of Set 6 | provideniya
# Processing Record 6 of Set 6 | tucuman
# Processing Record 7 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 6 | letterkenny
# Processing Record 9 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 6 | turayf
# Processing Record 11 of Set 6 | unye
# City not found. Skipping...
# Processing Record 12 of Set 6 | codrington
# Processing Record 13 of Set 6 | bayan
# Processing Record 14 of Set 6 | khandyga
# Processing Record 15 of Set 6 | tateyama
# Processing Record 16 of Set 6 | ust-tarka
# Processing Record 17 of Set 6 | luderitz
# Processing Record 18 of Set 6 | tadine
# Processing Record 19 of Set 6 | otaru
# Processing Record 20 of Set 6 | ancud
# Processing Record 21 of Set 6 | smithers
# Processing Record 22 of Set 6 | vostok
# Processing Record 23 of Set 6 | brae
# Processing Record 24 of Set 6 | pak phanang
# Processing Record 25 of Set 6 | havre-saint-pierre
# Processing Record 26 of Set 6 | nhulunbuy
# Processing Record 27 of Set 6 | pasni
# Processing Record 28 of Set 6 | vestmannaeyjar
# Processing Record 29 of Set 6 | conakry
# Processing Record 30 of Set 6 | klaksvik
# Processing Record 31 of Set 6 | isangel
# Processing Record 32 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 6 | rocha
# Processing Record 34 of Set 6 | sao filipe
# Processing Record 35 of Set 6 | nanortalik
# Processing Record 36 of Set 6 | mahebourg
# Processing Record 37 of Set 6 | camacha
# Processing Record 38 of Set 6 | isabela
# Processing Record 39 of Set 6 | miandrivazo
# Processing Record 40 of Set 6 | koson
# Processing Record 41 of Set 6 | tra vinh
# Processing Record 42 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 6 | luancheng
# Processing Record 44 of Set 6 | sorland
# Processing Record 45 of Set 6 | winslow
# Processing Record 46 of Set 6 | daxian
# City not found. Skipping...
# Processing Record 47 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 48 of Set 6 | lac du bonnet
# Processing Record 49 of Set 6 | sal rei
# Processing Record 0 of Set 7 | los llanos de aridane
# Processing Record 1 of Set 7 | dujuma
# City not found. Skipping...
# Processing Record 2 of Set 7 | simoes
# Processing Record 3 of Set 7 | sinjah
# City not found. Skipping...
# Processing Record 4 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 7 | torrington
# Processing Record 6 of Set 7 | te anau
# Processing Record 7 of Set 7 | joaima
# Processing Record 8 of Set 7 | gazli
# Processing Record 9 of Set 7 | lapas
# Processing Record 10 of Set 7 | rehoboth
# Processing Record 11 of Set 7 | roma
# Processing Record 12 of Set 7 | norman wells
# Processing Record 13 of Set 7 | puerto leguizamo
# Processing Record 14 of Set 7 | odienne
# Processing Record 15 of Set 7 | sabang
# Processing Record 16 of Set 7 | vila velha
# Processing Record 17 of Set 7 | mazurivka
# Processing Record 18 of Set 7 | gunjur
# Processing Record 19 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 7 | jalalabad
# Processing Record 21 of Set 7 | coronado
# Processing Record 22 of Set 7 | tura
# Processing Record 23 of Set 7 | pangnirtung
# Processing Record 24 of Set 7 | lipin bor
# Processing Record 25 of Set 7 | kall
# Processing Record 26 of Set 7 | henties bay
# Processing Record 27 of Set 7 | cockburn town
# Processing Record 28 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 29 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 7 | morant bay
# Processing Record 31 of Set 7 | yei
# Processing Record 32 of Set 7 | coihaique
# Processing Record 33 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 7 | bosaso
# Processing Record 35 of Set 7 | sao joao da barra
# Processing Record 36 of Set 7 | el faiyum
# City not found. Skipping...
# Processing Record 37 of Set 7 | la ronge
# Processing Record 38 of Set 7 | kourou
# Processing Record 39 of Set 7 | ulaanbaatar
# Processing Record 40 of Set 7 | andenes
# Processing Record 41 of Set 7 | tilsonburg
# City not found. Skipping...
# Processing Record 42 of Set 7 | coffs harbour
# Processing Record 43 of Set 7 | seabra
# Processing Record 44 of Set 7 | vardo
# Processing Record 45 of Set 7 | acarau
# Processing Record 46 of Set 7 | payo
# Processing Record 47 of Set 7 | valdivia
# Processing Record 48 of Set 7 | calvinia
# Processing Record 49 of Set 7 | ulmi
# Processing Record 0 of Set 8 | jilin
# Processing Record 1 of Set 8 | kavieng
# Processing Record 2 of Set 8 | lugoba
# Processing Record 3 of Set 8 | ventspils
# Processing Record 4 of Set 8 | alyangula
# Processing Record 5 of Set 8 | quatre cocos
# Processing Record 6 of Set 8 | general roca
# Processing Record 7 of Set 8 | port hawkesbury
# Processing Record 8 of Set 8 | iqaluit
# Processing Record 9 of Set 8 | lata
# Processing Record 10 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 11 of Set 8 | gizo
# Processing Record 12 of Set 8 | boyolangu
# Processing Record 13 of Set 8 | lerwick
# Processing Record 14 of Set 8 | hovd
# Processing Record 15 of Set 8 | andros
# Processing Record 16 of Set 8 | guerrero negro
# Processing Record 17 of Set 8 | tiksi
# Processing Record 18 of Set 8 | manta
# Processing Record 19 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 8 | mount isa
# Processing Record 21 of Set 8 | eskasem
# City not found. Skipping...
# Processing Record 22 of Set 8 | rio grande
# Processing Record 23 of Set 8 | piacabucu
# Processing Record 24 of Set 8 | fort nelson
# Processing Record 25 of Set 8 | takoradi
# Processing Record 26 of Set 8 | srandakan
# Processing Record 27 of Set 8 | vanderhoof
# Processing Record 28 of Set 8 | sorong
# Processing Record 29 of Set 8 | tezu
# Processing Record 30 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 8 | verkhnyaya inta
# Processing Record 33 of Set 8 | tarata
# Processing Record 34 of Set 8 | snasa
# Processing Record 35 of Set 8 | gwadar
# Processing Record 36 of Set 8 | port hardy
# Processing Record 37 of Set 8 | qianguo
# Processing Record 38 of Set 8 | ust-uda
# Processing Record 39 of Set 8 | saint-augustin
# Processing Record 40 of Set 8 | stykkisholmur
# Processing Record 41 of Set 8 | aswan
# Processing Record 42 of Set 8 | usinsk
# Processing Record 43 of Set 8 | wattegama
# Processing Record 44 of Set 8 | lasa
# Processing Record 45 of Set 8 | kapit
# Processing Record 46 of Set 8 | baruun-urt
# Processing Record 47 of Set 8 | tocopilla
# Processing Record 48 of Set 8 | mayo
# Processing Record 49 of Set 8 | kathu
# Processing Record 0 of Set 9 | ulaangom
# Processing Record 1 of Set 9 | dunedin
# Processing Record 2 of Set 9 | palu
# Processing Record 3 of Set 9 | meulaboh
# Processing Record 4 of Set 9 | chichli
# Processing Record 5 of Set 9 | coahuayana
# Processing Record 6 of Set 9 | oranjemund
# Processing Record 7 of Set 9 | gimli
# Processing Record 8 of Set 9 | solok
# Processing Record 9 of Set 9 | imbituba
# Processing Record 10 of Set 9 | bantou
# Processing Record 11 of Set 9 | monte azul paulista
# Processing Record 12 of Set 9 | whitefish
# Processing Record 13 of Set 9 | colares
# Processing Record 14 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 9 | csaszar
# Processing Record 16 of Set 9 | correntina
# Processing Record 17 of Set 9 | raiganj
# Processing Record 18 of Set 9 | mitsamiouli
# Processing Record 19 of Set 9 | erzin
# Processing Record 20 of Set 9 | zhigansk
# Processing Record 21 of Set 9 | chernyshevskiy
# Processing Record 22 of Set 9 | concordia
# Processing Record 23 of Set 9 | show low
# Processing Record 24 of Set 9 | kimbe
# Processing Record 25 of Set 9 | tingo maria
# Processing Record 26 of Set 9 | charters towers
# Processing Record 27 of Set 9 | longyearbyen
# Processing Record 28 of Set 9 | talnakh
# Processing Record 29 of Set 9 | shache
# Processing Record 30 of Set 9 | ngorongoro
# Processing Record 31 of Set 9 | yarovoye
# Processing Record 32 of Set 9 | senneterre
# Processing Record 33 of Set 9 | anta
# Processing Record 34 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 35 of Set 9 | tynne
# Processing Record 36 of Set 9 | el dorado
# Processing Record 37 of Set 9 | geresk
# City not found. Skipping...
# Processing Record 38 of Set 9 | yaan
# Processing Record 39 of Set 9 | teacapan
# Processing Record 40 of Set 9 | cleveland
# Processing Record 41 of Set 9 | xacmaz
# Processing Record 42 of Set 9 | lahuachaca
# Processing Record 43 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 44 of Set 9 | lagoa
# Processing Record 45 of Set 9 | boden
# Processing Record 46 of Set 9 | chapais
# Processing Record 47 of Set 9 | gat
# Processing Record 48 of Set 9 | kashary
# Processing Record 49 of Set 9 | kenai
# Processing Record 0 of Set 10 | zabolottya
# City not found. Skipping...
# Processing Record 1 of Set 10 | jawhar
# Processing Record 2 of Set 10 | purpe
# Processing Record 3 of Set 10 | griffith
# Processing Record 4 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 5 of Set 10 | guder
# Processing Record 6 of Set 10 | opuwo
# Processing Record 7 of Set 10 | porto nacional
# Processing Record 8 of Set 10 | san quintin
# Processing Record 9 of Set 10 | nantucket
# Processing Record 10 of Set 10 | saquarema
# Processing Record 11 of Set 10 | westport
# Processing Record 12 of Set 10 | barentu
# Processing Record 13 of Set 10 | thinadhoo
# Processing Record 14 of Set 10 | marks
# Processing Record 15 of Set 10 | ewo
# Processing Record 16 of Set 10 | chara
# Processing Record 17 of Set 10 | sisimiut
# Processing Record 18 of Set 10 | shibetsu
# Processing Record 19 of Set 10 | zaragoza
# Processing Record 20 of Set 10 | narasannapeta
# Processing Record 21 of Set 10 | namibe
# Processing Record 22 of Set 10 | chernogorsk
# Processing Record 23 of Set 10 | huichapan
# Processing Record 24 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 25 of Set 10 | toftir
# City not found. Skipping...
# Processing Record 26 of Set 10 | clyde river
# Processing Record 27 of Set 10 | sansai
# City not found. Skipping...
# Processing Record 28 of Set 10 | petrolandia
# City not found. Skipping...
# Processing Record 29 of Set 10 | carmen
# Processing Record 30 of Set 10 | deputatskiy
# Processing Record 31 of Set 10 | arteaga
# Processing Record 32 of Set 10 | tautira
# Processing Record 33 of Set 10 | denpasar
# Processing Record 34 of Set 10 | scarborough
# Processing Record 35 of Set 10 | west wendover
# Processing Record 36 of Set 10 | betera
# Processing Record 37 of Set 10 | lompoc
# Processing Record 38 of Set 10 | loubomo
# Processing Record 39 of Set 10 | jambi
# Processing Record 40 of Set 10 | cidreira
# Processing Record 41 of Set 10 | umm jarr
# City not found. Skipping...
# Processing Record 42 of Set 10 | beira
# Processing Record 43 of Set 10 | akyab
# Processing Record 44 of Set 10 | pascagoula
# Processing Record 45 of Set 10 | surgut
# Processing Record 46 of Set 10 | gawler
# Processing Record 47 of Set 10 | suileng
# Processing Record 48 of Set 10 | katiola
# Processing Record 49 of Set 10 | springbok
# Processing Record 0 of Set 11 | cururupu
# Processing Record 1 of Set 11 | ahipara
# Processing Record 2 of Set 11 | qaracala
# Processing Record 3 of Set 11 | cordoba
# Processing Record 4 of Set 11 | mareeba
# Processing Record 5 of Set 11 | alice springs
# Processing Record 6 of Set 11 | coromandel
# Processing Record 7 of Set 11 | evensk
# Processing Record 8 of Set 11 | tarsus
# Processing Record 9 of Set 11 | matara
# Processing Record 10 of Set 11 | fare
# Processing Record 11 of Set 11 | brazzaville
# Processing Record 12 of Set 11 | tabou
# Processing Record 13 of Set 11 | birjand
# Processing Record 14 of Set 11 | pemangkat
# Processing Record 15 of Set 11 | viedma
# Processing Record 16 of Set 11 | irbeyskoye
# Processing Record 17 of Set 11 | yasnyy
# Processing Record 18 of Set 11 | san cristobal
# Processing Record 19 of Set 11 | gigmoto
# Processing Record 20 of Set 11 | katsuura
# Processing Record 21 of Set 11 | esil
# Processing Record 22 of Set 11 | aksarka
# Processing Record 23 of Set 11 | ballina
# Processing Record 24 of Set 11 | genhe
# Processing Record 25 of Set 11 | shingu
# Processing Record 26 of Set 11 | daru
# Processing Record 27 of Set 11 | alta floresta
# Processing Record 28 of Set 11 | cuenca
# Processing Record 29 of Set 11 | itarema
# Processing Record 30 of Set 11 | simbahan
# Processing Record 31 of Set 11 | berlevag
# Processing Record 32 of Set 11 | san andres
# Processing Record 33 of Set 11 | mlowo
# Processing Record 34 of Set 11 | karratha
# Processing Record 35 of Set 11 | impfondo
# Processing Record 36 of Set 11 | santa rosa
# Processing Record 37 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 38 of Set 11 | mollendo
# Processing Record 39 of Set 11 | ellington
# Processing Record 40 of Set 11 | bhinmal
# Processing Record 41 of Set 11 | kasane
# Processing Record 42 of Set 11 | belozernyy
# Processing Record 43 of Set 11 | goderich
# Processing Record 44 of Set 11 | madaoua
# Processing Record 45 of Set 11 | vievis
# Processing Record 46 of Set 11 | nara
# Processing Record 47 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 48 of Set 11 | chipinge
# Processing Record 49 of Set 11 | montrose
# Processing Record 0 of Set 12 | flin flon
# Processing Record 1 of Set 12 | uyskoye
# Processing Record 2 of Set 12 | bengkulu
# Processing Record 3 of Set 12 | honiara
# Processing Record 4 of Set 12 | turukhansk
# Processing Record 5 of Set 12 | bjornevatn
# Processing Record 6 of Set 12 | alamor
# Processing Record 7 of Set 12 | sundargarh
# Processing Record 8 of Set 12 | sungaipenuh
# Processing Record 9 of Set 12 | skjaerhollen
# City not found. Skipping...
# Processing Record 10 of Set 12 | inhambane
# Processing Record 11 of Set 12 | chumikan
# Processing Record 12 of Set 12 | xai-xai
# Processing Record 13 of Set 12 | haines junction
# Processing Record 14 of Set 12 | gornopravdinsk
# Processing Record 15 of Set 12 | komsomolets
# Processing Record 16 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 17 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 18 of Set 12 | marfino
# Processing Record 19 of Set 12 | majene
# Processing Record 20 of Set 12 | balakhta
# Processing Record 21 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 22 of Set 12 | sadowara
# City not found. Skipping...
# Processing Record 23 of Set 12 | dandong
# Processing Record 24 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 12 | jijiga
# Processing Record 26 of Set 12 | khatanga
# Processing Record 27 of Set 12 | nyurba
# Processing Record 28 of Set 12 | onega
# Processing Record 29 of Set 12 | kahului
# Processing Record 30 of Set 12 | zaysan
# Processing Record 31 of Set 12 | villa carlos paz
# Processing Record 32 of Set 12 | grand gaube
# Processing Record 33 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 12 | aykhal
# Processing Record 35 of Set 12 | altamont
# Processing Record 36 of Set 12 | freeport
# Processing Record 37 of Set 12 | ambon
# Processing Record 38 of Set 12 | kota bahru
# Processing Record 39 of Set 12 | venado tuerto
# Processing Record 40 of Set 12 | kazaki
# Processing Record 41 of Set 12 | verkhoyansk
# Processing Record 42 of Set 12 | palmer
# Processing Record 43 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 12 | cabedelo
# Processing Record 45 of Set 12 | auki
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          539
# Lat           539
# Lng           539
# Max Temp      539
# Humidity      539
# Cloudiness    539
# Wind Speed    539
# Country       539
# Date          539
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0  iroquois falls  48.7669 -80.6831      1.04        96          95
# 1      toora-khem  52.4675  96.1100    -18.70        99          97
# 2       bathsheba  13.2167 -59.5167     28.34        69          40
# 3         husavik  66.0449 -17.3389      2.64        80         100
# 4          albany  42.6001 -73.9662      8.69        47           5
#
#    Wind Speed Country        Date
# 0        5.66      CA  1676396007
# 1        1.17      RU  1676396007
# 2        9.26      BB  1676396008
# 3        3.85      IS  1676396008
# 4        2.24      US  1676396008

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        iroquois falls  48.7669 -80.6831      1.04        96          95
# 1            toora-khem  52.4675  96.1100    -18.70        99          97
# 2             bathsheba  13.2167 -59.5167     28.34        69          40
# 3               husavik  66.0449 -17.3389      2.64        80         100
# 4                albany  42.6001 -73.9662      8.69        47           5
#
#          Wind Speed Country        Date
# City_ID
# 0              5.66      CA  1676396007
# 1              1.17      RU  1676396007
# 2              9.26      BB  1676396008
# 3              3.85      IS  1676396008
# 4              2.24      US  1676396008

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(     
    city_data_df["Lat"],
    city_data_df["Max Temp"],
    label = "Cities"
)
# Incorporate the other graph properties
plt.title("Latitude vs. Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Humidity"]
)

# Incorporate the other graph properties
plt.title("Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Cloudiness"]
)
# Incorporate the other graph properties
plt.title("Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

# Save the figure
plt.savefig("output_data/Fig3.png")
# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Wind Speed"]
)

# Incorporate the other graph properties
plt.title("Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):

    (slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.xlabel('Latitude')
    plt.ylabel('Temperature')
    plt.annotate(line_eq,(20,15),fontsize=15,color="red")
    print(f"The r-value is: {rvalue**2}")
    
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        iroquois falls  48.7669 -80.6831      1.04        96          95
# 1            toora-khem  52.4675  96.1100    -18.70        99          97
# 2             bathsheba  13.2167 -59.5167     28.34        69          40
# 3               husavik  66.0449 -17.3389      2.64        80         100
# 4                albany  42.6001 -73.9662      8.69        47           5
#
#          Wind Speed Country        Date
# City_ID
# 0              5.66      CA  1676396007
# 1              1.17      RU  1676396007
# 2              9.26      BB  1676396008
# 3              3.85      IS  1676396008
# 4              2.24      US  1676396008

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 5            kieta  -6.2167  155.6333     26.91        79         100
# 6        hithadhoo  -0.6000   73.0833     27.38        71          25
# 9         maragogi  -9.0122  -35.2225     29.05        59         100
# 10           pisco -13.7000  -76.2167     28.03        65           0
# 11          olinda  -8.0089  -34.8553     28.85        70          40
#
#          Wind Speed Country        Date
# City_ID
# 5              2.56      PG  1676396008
# 6              3.91      MV  1676396008
# 9              4.41      BR  1676396008
# 10             4.12      PE  1676396009
# 11             5.66      BR  1676396009

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plt.scatter(
    northern_hemi_df["Lat"]
    northern_hemi_df["Max Temp"]
) plot_linear_regression
# Out:
#   File "/var/folders/wz/bqm2y8zs607_rml397r900sc0000gn/T/ipykernel_54475/239168341.py", line 4
#     northern_hemi_df["Max Temp"]
#     ^
# SyntaxError: invalid syntax

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
